# %% [markdown]
# # Pandas Challenge Part 1

# %% [markdown]
# Import pandas as “pd”.
# Create three lists with five elements each.
# The first list should contain employees' first names, the second their last names, and the third should list their ages. You can make up this data.
# Create a data dictionary from the three lists.
# Create a pandas Series from the employee age list.
# Determine the average employee age.
# Write the Series to a CSV file.

# %%
import pandas as pd

# %%
dict = {'firstname':["chasity","brooke","james","ryan","pilar"],
        'lastname':["davis","lyn","dam","philip","smith"],
        'age':[37,24,65,33,28]}

data = pd.DataFrame(dict)

data
# Out:
#   firstname lastname  age
# 0   chasity    davis   37
# 1    brooke      lyn   24
# 2     james      dam   65
# 3      ryan   philip   33
# 4     pilar    smith   28

# %%
#ser = pd.Series(['Java','Spark','PySpark','Pandas','NumPy','Python',"Oracle"])

ser = pd.Series([37,24,65,33,28])

print(ser)
# Out:
# 0    37
# 1    24
# 2    65
# 3    33
# 4    28
# dtype: int64

# %%
ser.mean()
# Out:
# 37.4

# %%
ser.to_csv('age_series.csv')

# %% [markdown]
# # Pandas Challenge Part 2

# %% [markdown]
# Import 21st century MLB Batting.csv
# Download 21st century MLB Batting.csv into Python as a data frame.
# Print the first five items in the data frame.
# Print the last six items in the data frame.
# Determine the average of the HR column.
# Calculate the max of the SO column.
# Save the data frame as an Excel file.
# Create a subset of the data frame for players with more than 40 HR.
# Save this new subset as a json file.

# %%
import pandas as pd

# %%
df = pd.read_csv(r"/Users/Private/Downloads/21st century MLB Batting.csv")

# %%
df.head()
# Out:
#     playerID  yearID  stint teamID lgID    G   AB    R    H  2B  3B  HR  RBI  \
# 0  abbotje01    2000      1    CHA   AL   80  215   31   59  15   1   3   29
# 1  abbotku01    2000      1    NYN   NL   79  157   22   34   7   1   6   12
# 2  abbotpa01    2000      1    SEA   AL   35    5    1    2   1   0   0    0
# 3  abreubo01    2000      1    PHI   NL  154  576  103  182  42  10  25   79
# 4  aceveju01    2000      1    MIL   NL   62    1    1    0   0   0   0    0
#
#    SB  CS   BB   SO
# 0   2   1   21   38
# 1   1   1   14   51
# 2   0   0    0    1
# 3  28   8  100  116
# 4   0   0    1    1

# %%
df.tail()
# Out:
#         playerID  yearID  stint teamID lgID   G   AB   R   H  2B  3B  HR  RBI  \
# 28158  zimmejo02    2019      1    DET   AL  23    2   0   0   0   0   0    0
# 28159  zimmeky01    2019      1    KCA   AL  15    0   0   0   0   0   0    0
# 28160  zimmery01    2019      1    WAS   NL  52  171  20  44   9   0   6   27
# 28161  zobribe01    2019      1    CHN   NL  47  150  24  39   5   0   1   17
# 28162  zuninmi01    2019      1    TBA   AL  90  266  30  44  10   1   9   32
#
#        SB  CS  BB  SO
# 28158   0   0   0   2
# 28159   0   0   0   0
# 28160   0   0  17  39
# 28161   0   0  23  24
# 28162   0   0  20  98

# %%
df.dtypes
# Out:
# playerID    object
# yearID       int64
# stint        int64
# teamID      object
# lgID        object
# G            int64
# AB           int64
# R            int64
# H            int64
# 2B           int64
# 3B           int64
# HR           int64
# RBI          int64
# SB           int64
# CS           int64
# BB           int64
# SO           int64
# dtype: object

# %%
df.HR.mean()
# Out:
# 3.695593509214217

# %%
df.SO.max()
# Out:
# 223

# %%
df.to_excel('baseball_stats_analayzed.xlsx')

# %%
#new_dataframe = df.loc[:,'Region':'Net migration']
#df_retired = df[df['job']=='retired']

#df_over_40 = df[df['HR'] > 40]
df_over_40.head()
# Out:
#       playerID  yearID  stint teamID lgID    G   AB    R    H  2B  3B  HR  \
# 55   bagweje01    2000      1    HOU   NL  159  590  152  183  37   1  47
# 72   batisto01    2000      1    TOR   AL  154  620   96  163  32   2  41
# 127  bondsba01    2000      1    SFN   NL  143  480  129  147  28   4  49
# 300  delgaca01    2000      1    TOR   AL  162  569  115  196  57   1  41
# 341  edmonji01    2000      1    SLN   NL  152  525  129  155  25   0  42
#
#      RBI  SB  CS   BB   SO
# 55   132   9   6  107  116
# 72   114   5   4   35  121
# 127  106  11   3  117   77
# 300  137   0   1  123  104
# 341  108  10   3  103  167

# %%
df_over_40.to_json('df_over_40.json')
